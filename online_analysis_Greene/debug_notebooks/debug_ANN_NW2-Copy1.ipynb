# %%
import xarray as xr
import matplotlib.pyplot as plt
from xgcm import Grid
import numpy as np

# %%
import sys
sys.path.append('/home/db194/mom6_notebooks/helpers/')
from plot_helpers import *

# %%
dir = '/scratch/db194/mom6/mar2025/NW2/'

output_dir = 'output/'

# %%
import glob
files = sorted(glob.glob(dir + 'ANN_Cp3_hmin5/'  + "snapshots_*.nc")) 
ds_Cp3_snapshots = xr.open_mfdataset(files, 
                                   decode_times=False)

# %%
import glob
files = sorted(glob.glob(dir + 'ANN_Cp3_hmin5_w_EOS/'  + "snapshots_*.nc")) 
ds_Cp3_EOS_snapshots = xr.open_mfdataset(files, 
                                   decode_times=False)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /ext3/miniforge/share/proj failed

# %%
ds_Cp3_EOS_snapshots
# Out:
# <xarray.Dataset>
# Dimensions:  (xq: 241, yh: 560, zl: 15, time: 400, xh: 240, yq: 561, zi: 16)
# Coordinates:
#   * xq       (xq) float64 0.0 0.25 0.5 0.75 1.0 ... 59.0 59.25 59.5 59.75 60.0
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * zl       (zl) float64 1.023e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
#   * time     (time) float64 3.3e+04 3.301e+04 3.302e+04 ... 3.5e+04 3.5e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88
#   * yq       (yq) float64 -70.0 -69.75 -69.5 -69.25 ... 69.25 69.5 69.75 70.0
#   * zi       (zi) float64 1.022e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
# Data variables: (12/17)
#     u        (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     v        (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     uh       (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vh       (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     h        (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     e        (time, zi, yh, xh) float64 dask.array<chunksize=(5, 16, 560, 240), meta=np.ndarray>
#     ...       ...
#     dudy     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     dvdx     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fx       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fy       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     uhTrANN  (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vhTrANN  (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
# Attributes:
#     filename:          snapshots_00033005.nc
#     title:             NeverWorld2
#     associated_files:  area_t: static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %%
np.log(ds_Cp3_EOS_snapshots.h).isel(zl=0, time=-1).plot()

# %%
np.log(ds_Cp3_snapshots.h).isel(zl=0, time=-1).plot()

# %%
import sys
sys.path.append('/home/db194/mom6_notebooks/helpers/')
from plot_helpers import *

# %%
dir = '/scratch/db194/mom6/mar2025/NW2/'

output_dir = 'output/'

# %%
exp_dir = 'bare/'
#ds_HR_snapshots = xr.open_mfdataset(dir + exp_dir + output_dir +'snapshots_*.nc', 
#                                   decode_times=False)

stats_HR = xr.open_dataset(dir + exp_dir + output_dir +'ocean.stats.nc')
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /ext3/miniforge/share/proj failed

# %%
stats_HR['Time'] = stats_HR['Time'].dt.days

# %%
exp_dir = 'ANN_C0/'
#ds_C0_snapshots = xr.open_mfdataset(dir + exp_dir  +'snapshots*.nc', 
#                                   decode_times=False)
stats_C0 = xr.open_dataset(dir + exp_dir  +'ocean.stats.nc')

# %%
exp_dir = 'ANN_Cp2/'
#ds_Cp2_snapshots = xr.open_mfdataset(dir + exp_dir  +'snapshots*.nc', 
#                                   decode_times=False)
stats_Cp2 = xr.open_dataset(dir + exp_dir  +'ocean.stats.nc')

# %%
exp_dir = 'ANN_Cp2_hmin5/'
#ds_Cp2_snapshots = xr.open_mfdataset(dir + exp_dir  +'snapshots*.nc', 
#                                   decode_times=False)
stats_Cp2_hmin5 = xr.open_dataset(dir + exp_dir  +'ocean.stats.nc')

# %%
exp_dir = 'ANN_Cp3_hmin5/'
#ds_Cp3_snapshots = xr.open_mfdataset(dir + exp_dir  +'snapshots*.nc', 
#                                   decode_times=False)
stats_Cp3_1 = xr.open_dataset(dir + exp_dir  +'ocean.stats_30000_31000.nc')
stats_Cp3_1['Time'] = stats_Cp3_1['Time'].dt.days
stats_Cp3_2 = xr.open_dataset(dir + exp_dir  +'ocean.stats_31001_33000.nc')
stats_Cp3_2['Time'] = stats_Cp3_2['Time'].dt.days
stats_Cp3_3 = xr.open_dataset(dir + exp_dir  +'ocean.stats.nc')
stats_Cp3_3['Time'] = stats_Cp3_3['Time'].dt.days

# %%
exp_dir = 'ANN_Cp3_hmin5_w_EOS/'

stats_Cp_3new = xr.open_dataset(dir+exp_dir + 'ocean.stats.nc')
stats_Cp_3new['Time'] = stats_Cp_3new['Time'].dt.days

# %%
exp_dir = 'ANN_Cp5_hmin5_w_EOS/'

stats_Cp_5new = xr.open_dataset(dir+exp_dir + 'ocean.stats.nc')
stats_Cp_5new['Time'] = stats_Cp_5new['Time'].dt.days

# %%
plt.figure(figsize=(8,3))

plt.subplot(121)
stats_Cp3_3.APE.sum('Interface').plot(label='Old .3 ')
stats_Cp_3new.APE.sum('Interface').plot(label='New .3')
stats_Cp_5new.APE.sum('Interface').plot(label='New .5')
plt.legend()

plt.subplot(122)
stats_Cp3_3.KE.sum('Layer').plot()
stats_Cp_3new.KE.sum('Layer').plot()
stats_Cp_5new.KE.sum('Layer').plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3))

plt.subplot(121)
stats_HR.APE.sum('Interface')[0:].plot(label='Unparameterized')
stats_Cp3_1.APE.sum('Interface').plot(color='r', label='3 point ANN param')
stats_Cp3_2.APE.sum('Interface').plot(color='r')
stats_Cp3_3.APE.sum('Interface').plot(color='r')
stats_Cp_new.APE.sum('Interface').plot(color='k')
#stats_Cp3_2.APE.sum('Interface').plot()
plt.grid()
plt.hlines(9.58e19, 0, 35000, linestyles='--', color='k', label='High res APE expected')
#plt.ylim([.96e20, 1.05e20])
plt.legend()


plt.subplot(122)
stats_HR.KE.sum('Layer')[0:].plot(label='Unparameterized')
stats_Cp3_1.KE.sum('Layer').plot(color='r', label='3 point ANN param')
stats_Cp3_2.KE.sum('Layer').plot(color='r')
stats_Cp3_3.KE.sum('Layer').plot(color='r')
stats_Cp_new.KE.sum('Layer').plot(color='k')
#stats_Cp3_2.APE.sum('Interface').plot()
plt.grid()
plt.hlines(.85e18, 0, 35000, linestyles='--', color='k', label='Target')
#plt.ylim([.96e20, 1.05e20])
#plt.legend()
plt.tight_layout()

# %%
plt.figure(figsize=(15, 4))

plt.subplot(131)
stats_HR.APE.sum('Interface').plot(label='HR')
stats_C0.APE.sum('Interface').plot(label='HR extend')
#stats_Cp2.APE.sum('Interface').plot(label='LR, ANN C=0.2, hmin=1')
stats_Cp2_hmin5.APE.sum('Interface').plot(label='LR, ANN C=0.2, hmin=5')
#stats_Cp3.APE.sum('Interface').plot(label='LR, ANN C=0.3, hmin=5')
stats_Cp3_1.APE.sum('Interface').plot(label='LR, ANN C=0.3, hmin=5')
stats_Cp3_2.APE.sum('Interface').plot(label='LR, ANN C=0.3, hmin=5')
plt.grid()
plt.hlines(9.3e19, 0, 3e18, linestyles='--', color='k')

#plt.ylim([.96e20, 1.05e20])
plt.legend()

plt.subplot(133)
stats_HR.max_CFL_lin.plot()
stats_C0.max_CFL_lin.plot()
#stats_Cp2.max_CFL_lin.plot()
stats_Cp2_hmin5.max_CFL_lin.plot()
stats_Cp3_1.max_CFL_lin.plot()
stats_Cp3_2.max_CFL_lin.plot()

plt.subplot(132)
stats_HR.KE.sum('Layer').plot()
stats_C0.KE.sum('Layer').plot()
#stats_Cp2.KE.sum('Layer').plot()
stats_Cp2_hmin5.KE.sum('Layer').plot()
stats_Cp3_1.KE.sum('Layer').plot()
stats_Cp3_2.KE.sum('Layer').plot()

plt.tight_layout()

# %%
import glob
files = sorted(glob.glob(dir + 'ANN_Cp3_hmin5/'  + "snapshots_*.nc")) 
ds_Cp3_snapshots = xr.open_mfdataset(files, 
                                   decode_times=False)

# %%
ds_Cp3_snapshots
# Out:
# <xarray.Dataset>
# Dimensions:  (xq: 241, yh: 560, zl: 15, time: 1000, xh: 240, yq: 561, zi: 16)
# Coordinates:
#   * xq       (xq) float64 0.0 0.25 0.5 0.75 1.0 ... 59.0 59.25 59.5 59.75 60.0
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * zl       (zl) float64 1.023e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
#   * time     (time) float64 3e+04 3.001e+04 3.002e+04 ... 3.5e+04 3.5e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88
#   * yq       (yq) float64 -70.0 -69.75 -69.5 -69.25 ... 69.25 69.5 69.75 70.0
#   * zi       (zi) float64 1.022e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
# Data variables: (12/17)
#     u        (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     v        (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     uh       (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vh       (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     h        (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     e        (time, zi, yh, xh) float64 dask.array<chunksize=(5, 16, 560, 240), meta=np.ndarray>
#     ...       ...
#     dudy     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     dvdx     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fx       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fy       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     uhTrANN  (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vhTrANN  (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
# Attributes:
#     filename:          snapshots_00030005.nc
#     title:             NeverWorld2
#     associated_files:  area_t: static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %%
import glob
files = sorted(glob.glob(dir + 'ANN_Cp3_hmin5_w_EOS/'  + "snapshots_*.nc")) 
ds_Cp3_EOS_snapshots = xr.open_mfdataset(files, 
                                   decode_times=False)

# %%
ds_Cp3_EOS_snapshots
# Out:
# <xarray.Dataset>
# Dimensions:  (xq: 241, yh: 560, zl: 15, time: 400, xh: 240, yq: 561, zi: 16)
# Coordinates:
#   * xq       (xq) float64 0.0 0.25 0.5 0.75 1.0 ... 59.0 59.25 59.5 59.75 60.0
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * zl       (zl) float64 1.023e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
#   * time     (time) float64 3.3e+04 3.301e+04 3.302e+04 ... 3.5e+04 3.5e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88
#   * yq       (yq) float64 -70.0 -69.75 -69.5 -69.25 ... 69.25 69.5 69.75 70.0
#   * zi       (zi) float64 1.022e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
# Data variables: (12/17)
#     u        (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     v        (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     uh       (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vh       (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     h        (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     e        (time, zi, yh, xh) float64 dask.array<chunksize=(5, 16, 560, 240), meta=np.ndarray>
#     ...       ...
#     dudy     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     dvdx     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fx       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fy       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     uhTrANN  (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vhTrANN  (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
# Attributes:
#     filename:          snapshots_00033005.nc
#     title:             NeverWorld2
#     associated_files:  area_t: static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %%
plt.figure(figsize=(8,6))

plt.subplot(121)
ds_Cp3_snapshots.vhTrANN.isel(time=-1, zl=10).plot(robust=True)


plt.subplot(122)
ds_Cp3_EOS_snapshots.vhTrANN.isel(time=-1, zl=10).plot(robust=True)

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.vhTrANN.isel(time=slice(-10, -1)).mean('xh').plot(vmin=-2000)


plt.subplot(212)
ds_Cp3_EOS_snapshots.vhTrANN.isel(time==slice(-10, -1)).mean('xh').plot(vmin=-2000)

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.vhTrANN.isel(time=slice(-20, -1)).mean(['xh','time']).plot(vmin=-2000)
plt.gca().invert_yaxis()

plt.subplot(212)
ds_Cp3_EOS_snapshots.vhTrANN.isel(time=slice(-20, -1)).mean(['xh','time']).plot(vmin=-2000)
plt.gca().invert_yaxis()

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.h.isel(time=slice(-20, -1)).mean(['xh','time']).plot(robust=True)
plt.gca().invert_yaxis()

plt.subplot(212)
ds_Cp3_EOS_snapshots.h.isel(time=slice(-20, -1)).mean(['xh','time']).plot(robust=True)
plt.gca().invert_yaxis()

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.e.isel(time=slice(-20, -1)).mean(['xh','time']).plot(vmin=-2000)
plt.gca().invert_yaxis()

plt.subplot(212)
ds_Cp3_EOS_snapshots.e.isel(time=slice(-20, -1)).mean(['xh','time']).plot(vmin=-2000)
plt.gca().invert_yaxis()

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.vhTrANN.isel(time=-1, xh=10).plot(vmin=-2000)


plt.subplot(212)
ds_Cp3_EOS_snapshots.vhTrANN.isel(time=-1, xh=10).plot(vmin=-2000)

plt.tight_layout()

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.vhTrANN.isel(time=-1, xh=10).plot(vmin=-500)


plt.subplot(212)
ds_Cp3_EOS_snapshots.vhTrANN.isel(time=-1, xh=10).plot(vmin=-500)

plt.tight_layout()

# %%
ds_Cp3_EOS_snapshots.e.
# Out:
# <xarray.DataArray 'e' (time: 400, zi: 16, yh: 560, xh: 240)>
# dask.array<concatenate, shape=(400, 16, 560, 240), dtype=float64, chunksize=(5, 16, 560, 240), chunktype=numpy.ndarray>
# Coordinates:
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * time     (time) float64 3.3e+04 3.301e+04 3.302e+04 ... 3.5e+04 3.5e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88
#   * zi       (zi) float64 1.022e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
# Attributes:
#     long_name:      Interface Height Relative to Mean Sea Level
#     units:          m
#     cell_methods:   area:mean zi:point yh:mean xh:mean time: point
#     cell_measures:  area: area_t

# %%
plt.figure(figsize=(8,6))

plt.subplot(211)
ds_Cp3_snapshots.vhTrANN.isel(time=-1, xh=10).plot(vmin=-2000)


plt.subplot(212)
ds_Cp3_EOS_snapshots.vhTrANN.isel(time=-1, xh=10).plot(vmin=-2000)

plt.tight_layout()

# %%
ds_Cp3_EOS_snapshots
# Out:
# <xarray.Dataset>
# Dimensions:  (xq: 241, yh: 560, zl: 15, time: 400, xh: 240, yq: 561, zi: 16)
# Coordinates:
#   * xq       (xq) float64 0.0 0.25 0.5 0.75 1.0 ... 59.0 59.25 59.5 59.75 60.0
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * zl       (zl) float64 1.023e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
#   * time     (time) float64 3.3e+04 3.301e+04 3.302e+04 ... 3.5e+04 3.5e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88
#   * yq       (yq) float64 -70.0 -69.75 -69.5 -69.25 ... 69.25 69.5 69.75 70.0
#   * zi       (zi) float64 1.022e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
# Data variables: (12/17)
#     u        (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     v        (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     uh       (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vh       (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     h        (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     e        (time, zi, yh, xh) float64 dask.array<chunksize=(5, 16, 560, 240), meta=np.ndarray>
#     ...       ...
#     dudy     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     dvdx     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fx       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fy       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     uhTrANN  (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vhTrANN  (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
# Attributes:
#     filename:          snapshots_00033005.nc
#     title:             NeverWorld2
#     associated_files:  area_t: static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %%
def APE(interface):
    '''
    Returns APE in units of kinetic energy per unit mass, i.e.
    m^3/s^2
    '''
    interface_rest = xr.DataArray([    0.,   -25.,   -75.,  -175.,  -300.,  -450.,  -625.,  -825.,
       -1050., -1300., -1600., -1950., -2350., -2850., -3400., -4000.], dims='zi')
    g = xr.DataArray([1.0e+01, 2.1e-03, 3.9e-03, 5.4e-03, 5.8e-03, 5.8e-03, 5.7e-03,
       5.3e-03, 4.8e-03, 4.2e-03, 3.7e-03, 3.1e-03, 2.4e-03, 1.7e-03,
       1.1e-03, 0.0e+00], dims='zi')
    
    coordinate_of_bottom = interface.isel(zi=-1).drop_vars(['zi'])
    
    hint = interface - interface_rest
    
    # Where bottom is upper than the rest interface
    hbot = np.maximum(coordinate_of_bottom - interface_rest,0)
    
    APE_instant = (0.5 * g * (hint**2))
    APE_constant = (0.5 * g * (hbot**2))
    
    return (APE_instant - APE_constant).sum('zi')

# %%
ape_Cp3 = APE(ds_Cp3_snapshots.e) 
ape_Cp3_EOS = APE(ds_Cp3_EOS_snapshots.e)

# %%
ape_Cp3
# Out:
# <xarray.DataArray (time: 1000, yh: 560, xh: 240)>
# dask.array<sum-aggregate, shape=(1000, 560, 240), dtype=float64, chunksize=(5, 560, 240), chunktype=numpy.ndarray>
# Coordinates:
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * time     (time) float64 3e+04 3.001e+04 3.002e+04 ... 3.5e+04 3.5e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88

# %%
plt.figure(figsize=(12, 5))

plt.subplot(131)
ape_Cp3.isel(time=0).plot()
plt.title('Initial')

plt.subplot(132)
ape_Cp3.isel(time=-1).plot()
plt.title('Final')

plt.subplot(133)
(ape_Cp3.isel(time=-1) - ape_Cp3.isel(time=0)).plot(robust=True)
plt.title('Final - Initial')

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /ext3/miniforge/lib/python3.10/site-packages/dask/base.py:628, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     627 with shorten_traceback():
# --> 628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /ext3/miniforge/lib/python3.10/site-packages/dask/threaded.py:90, in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      88         pool = MultiprocessingPoolExecutor(pool)
# ---> 90 results = get_async(
#      91     pool.submit,
#      92     pool._max_workers,
#      93     dsk,
#      94     keys,
#      95     cache=cache,
#      96     get_id=_thread_get_id,
#      97     pack_exception=pack_exception,
#      98     **kwargs,
#      99 )
#     101 # Cleanup pools associated to dead threads
#
# File /ext3/miniforge/lib/python3.10/site-packages/dask/local.py:501, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     500 fire_tasks(chunksize)
# --> 501 for key, res_info, failed in queue_get(queue).result():
#     502     if failed:
#
# File /ext3/miniforge/lib/python3.10/site-packages/dask/local.py:138, in queue_get(q)
#     137 def queue_get(q):
# --> 138     return q.get()
#
# File /ext3/miniforge/lib/python3.10/queue.py:171, in Queue.get(self, block, timeout)
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#
# File /ext3/miniforge/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 4
#       1 plt.figure(figsize=(12, 5))
#       3 plt.subplot(131)
# ----> 4 ape_Cp3.isel(time=0).plot()
#       5 plt.title('Initial')
#       7 plt.subplot(132)
#
# File /ext3/miniforge/lib/python3.10/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File /ext3/miniforge/lib/python3.10/site-packages/xarray/plot/dataarray_plot.py:269, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     218 def plot(
#     219     darray: DataArray,
#     220     *,
#    (...)
#     227     **kwargs: Any,
#     228 ) -> Any:
#     229     """
#     230     Default plot of DataArray using :py:mod:`matplotlib:matplotlib.pyplot`.
#     231
#    (...)
#     265     xarray.DataArray.squeeze
#     266     """
#     267     darray = darray.squeeze(
#     268         d for d, s in darray.sizes.items() if s == 1 and d not in (row, col, hue)
# --> 269     ).compute()
#     271     plot_dims = set(darray.dims)
#     272     plot_dims.discard(row)
#
# File /ext3/miniforge/lib/python3.10/site-packages/xarray/core/dataarray.py:1148, in DataArray.compute(self, **kwargs)
#    1129 """Manually trigger loading of this array's data from disk or a
#    1130 remote source into memory and return a new array. The original is
#    1131 left unaltered.
#    (...)
#    1145 dask.compute
#    1146 """
#    1147 new = self.copy(deep=False)
# -> 1148 return new.load(**kwargs)
#
# File /ext3/miniforge/lib/python3.10/site-packages/xarray/core/dataarray.py:1122, in DataArray.load(self, **kwargs)
#    1104 def load(self, **kwargs) -> Self:
#    1105     """Manually trigger loading of this array's data from disk or a
#    1106     remote source into memory and return this array.
#    1107
#    (...)
#    1120     dask.compute
#    1121     """
# -> 1122     ds = self._to_temp_dataset().load(**kwargs)
#    1123     new = self._from_temp_dataset(ds)
#    1124     self._variable = new._variable
#
# File /ext3/miniforge/lib/python3.10/site-packages/xarray/core/dataset.py:847, in Dataset.load(self, **kwargs)
#     844 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     846 # evaluate all the chunked arrays simultaneously
# --> 847 evaluated_data = chunkmanager.compute(*lazy_data.values(), **kwargs)
#     849 for k, data in zip(lazy_data, evaluated_data):
#     850     self.variables[k].data = data
#
# File /ext3/miniforge/lib/python3.10/site-packages/xarray/core/daskmanager.py:70, in DaskManager.compute(self, *data, **kwargs)
#      67 def compute(self, *data: DaskArray, **kwargs) -> tuple[np.ndarray, ...]:
#      68     from dask.array import compute
# ---> 70     return compute(*data, **kwargs)
#
# File /ext3/miniforge/lib/python3.10/site-packages/dask/base.py:627, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     624     keys.append(x.__dask_keys__())
#     625     postcomputes.append(x.__dask_postcompute__())
# --> 627 with shorten_traceback():
#     628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /ext3/miniforge/lib/python3.10/site-packages/dask/utils.py:2151, in shorten_traceback.__exit__(self, exc_type, exc_val, exc_tb)
#    2148 def __enter__(self) -> None:
#    2149     pass
# -> 2151 def __exit__(
#    2152     self,
#    2153     exc_type: type[BaseException] | None,
#    2154     exc_val: BaseException | None,
#    2155     exc_tb: types.TracebackType | None,
#    2156 ) -> None:
#    2157     if exc_val and exc_tb:
#    2158         exc_val.__traceback__ = self.shorten(exc_tb)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(12, 5))

plt.subplot(131)
ape_Cp3_EOS.isel(time=0).plot()
plt.title('Initial')

plt.subplot(132)
ape_Cp3_EOS.isel(time=-1).plot()
plt.title('Final')

plt.subplot(133)
(ape_Cp3_EOS.isel(time=-1) - ape_Cp3.isel(time=0)).plot(robust=True)
plt.title('Final - Initial')

plt.tight_layout()

# %%
plt.figure(figsize=(8, 5))

plt.subplot(121)
(ape_Cp3.isel(time=-1) - ape_Cp3.isel(time=0)).plot(vmin=-1600)
plt.title('Final - Initial')

plt.subplot(122)
(ape_Cp3_EOS.isel(time=-1) - ape_Cp3_EOS.isel(time=0)).plot(vmin=-1600)

plt.tight_layout()

# %%
ape_change = ( ape.isel(time=slice(-72,None)).mean('time') - ape.isel(time=slice(0,50)).mean('time') )
ape_change.load();

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm

plt.figure(figsize=(4, 5.5))

ape_change.plot(
    norm=SymLogNorm(linthresh=50, vmin=-1000, vmax=1000),
    cmap='RdBu_r'  # or another diverging colormap
)

plt.title('Final year - Initial year')
plt.xlabel('Lon')
plt.ylabel('Lat')
plt.tight_layout()
plt.savefig('APE_change.png')

# %%
plt.figure(figsize=(12, 5))

plt.subplot(131)
ape.isel(time=slice(0,72)).mean('time').plot(vmax=14e3)
plt.title('Initial')

plt.subplot(132)
ape.isel(time=slice(-72,None)).mean('time').plot(vmax=14e3)
plt.title('Final')

plt.subplot(133)
( ape.isel(time=slice(-72,None)).mean('time') - ape.isel(time=slice(0,50)).mean('time') ).plot(vmin=-1000)
plt.title('Final - Initial')

plt.tight_layout()

# %%
( ape.isel(time=slice(-50,None)).mean('time') - ape.isel(time=slice(0,50)).mean('time') ).plot.hist(bins=51)
plt.yscale('log')
plt.grid()
plt.xlabel('APE final - initial')
# Out:
# Text(0.5, 0, 'APE final - initial')

# %%
plt.figure(figsize=(12, 5))

plt.subplot(121)
for i in range(16):
    ds_Cp3_EOS_snapshots.e.isel(time=0, zi = i).sel(xh=30, method='nearest').plot()

plt.subplot(122)
for i in range(16):
    ds_Cp3_EOS_snapshots.e.isel(time=-1, zi = i).sel(xh=30, method='nearest').plot()
plt.tight_layout()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(121)
for i in range(16):
    ds_Cp3_snapshots.e.isel(time=0, zi = i).sel(xh=30, method='nearest').plot()

plt.subplot(122)
for i in range(16):
    ds_Cp3_snapshots.e.isel(time=-1, zi = i).sel(xh=30, method='nearest').plot()
plt.tight_layout()

# %%
plt.figure(figsize=(6, 5))

for i in range(16):
    ds_Cp3_snapshots.e.isel(time=slice(0,20), zi = i).sel(xh=0, method='nearest').mean('time').plot(color='k')
    ds_Cp3_snapshots.e.isel(time=slice(-20,None), zi = i).sel(xh=0, method='nearest').mean('time').plot(linestyle='--', color='b')

plt.grid()

# %%
plt.figure(figsize=(6, 5))

for i in range(16):
    ds_Cp3_EOS_snapshots.e.isel(time=slice(0,20), zi = i).sel(xh=0, method='nearest').mean('time').plot(color='k')
    ds_Cp3_EOS_snapshots.e.isel(time=slice(-20,None), zi = i).sel(xh=0, method='nearest').mean('time').plot(linestyle='--', color='b')

plt.grid()

# %%
plt.figure(figsize=(6, 5))

for i in range(16):
    ds_Cp3_snapshots.e.isel(time=slice(0,20), zi = i).sel(xh=10, method='nearest').mean('time').plot(color='k')
    ds_Cp3_snapshots.e.isel(time=slice(-20,None), zi = i).sel(xh=10, method='nearest').mean('time').plot(linestyle='--', color='b')

plt.grid()

# %%
plt.figure(figsize=(8, 5))
xh = 40
for i in range(16):
    ds_Cp3_snapshots.e.isel(time=slice(0,20), zi = i).sel(xh=xh, method='nearest').mean('time').plot(color='k')
    ds_Cp3_snapshots.e.isel(time=slice(-20,None), zi = i).sel(xh=xh, method='nearest').mean('time').plot(linestyle='--', color='b')

plt.grid()

# %%
plt.figure(figsize=(8, 5))
xh = 50
for i in range(16):
    ds_Cp3_snapshots.e.isel(time=slice(0,20), zi = i).sel(xh=xh, method='nearest').mean('time').plot(color='k')
    ds_Cp3_snapshots.e.isel(time=slice(-20,None), zi = i).sel(xh=xh, method='nearest').mean('time').plot(linestyle='--', color='b')

plt.grid()

# %%
from xgcm import Grid

grid = Grid(ds_Cp3_snapshots)

# %%
ds_Cp3_snapshots
# Out:
# <xarray.Dataset>
# Dimensions:  (xq: 241, yh: 560, zl: 15, time: 200, xh: 240, yq: 561, zi: 16)
# Coordinates:
#   * xq       (xq) float64 0.0 0.25 0.5 0.75 1.0 ... 59.0 59.25 59.5 59.75 60.0
#   * yh       (yh) float64 -69.88 -69.62 -69.38 -69.12 ... 69.38 69.62 69.88
#   * zl       (zl) float64 1.023e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
#   * time     (time) float64 3e+04 3.001e+04 3.002e+04 ... 3.1e+04 3.1e+04
#   * xh       (xh) float64 0.125 0.375 0.625 0.875 ... 59.12 59.38 59.62 59.88
#   * yq       (yq) float64 -70.0 -69.75 -69.5 -69.25 ... 69.25 69.5 69.75 70.0
#   * zi       (zi) float64 1.022e+03 1.023e+03 1.023e+03 ... 1.028e+03 1.028e+03
# Data variables: (12/17)
#     u        (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     v        (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     uh       (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vh       (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
#     h        (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     e        (time, zi, yh, xh) float64 dask.array<chunksize=(5, 16, 560, 240), meta=np.ndarray>
#     ...       ...
#     dudy     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     dvdx     (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fx       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     Fy       (time, zl, yh, xh) float64 dask.array<chunksize=(5, 15, 560, 240), meta=np.ndarray>
#     uhTrANN  (time, zl, yh, xq) float64 dask.array<chunksize=(5, 15, 560, 241), meta=np.ndarray>
#     vhTrANN  (time, zl, yq, xh) float64 dask.array<chunksize=(5, 15, 561, 240), meta=np.ndarray>
# Attributes:
#     filename:          snapshots_00030005.nc
#     title:             NeverWorld2
#     associated_files:  area_t: static.nc
#     grid_type:         regular
#     grid_tile:         N/A

# %%
grid

# %%
PE_init = ((ds_Cp3_snapshots.e + 4000)**2).isel(time=slice(0,30)).sum('zi').mean('time')
PE_final = ((ds_Cp3_snapshots.e + 4000)**2).isel(time=slice(-30,None)).sum('zi').mean('time')

# %%
(PE_final - PE_init).plot(robust=True)

# %%
KE_init = (ds_Cp3_snapshots.u**2 * ds_Cp3_snapshots.h).isel(time=slice(0,20)).sum('zl').mean('time')
KE_final = (ds_Cp3_snapshots.u**2 * ds_Cp3_snapshots.h).isel(time=slice(-20,None)).sum('zl').mean('time')

# %%
KE_init.plot()

# %%
KE_final.plot()

# %%
for i in range(15):
    ds_Cp3_snapshots.h.isel(time=-1, zl = i).sel(xh=30, method='nearest').plot()

# %%
magGradh = (ds_Cp2_snapshots.dhdx**2 + ds_Cp2_snapshots.dhdy**2) ** 0.5
diss_Cp2 = (ds_Cp2_snapshots.Fx * ds_Cp2_snapshots.dhdx + ds_Cp2_snapshots.Fy * ds_Cp2_snapshots.dhdy)/magGradh

# %%
diss_Cp2.load();

# %%
magGradh = (ds_C0_snapshots.dhdx**2 + ds_C0_snapshots.dhdy**2) ** 0.5
diss_C0 = (ds_C0_snapshots.Fx * ds_C0_snapshots.dhdx + ds_C0_snapshots.Fy * ds_C0_snapshots.dhdy)/magGradh

# %%
diss_C0.load();

# %%
plt.figure(figsize=(12, 10))

plt.subplot(1,2,1)
diss_C0.isel(time=-1).sum('zl').plot(robust=True)


plt.subplot(1,2,2)
diss_Cp2.isel(time=-1).sum('zl').plot(robust=True)

plt.tight_layout()
# Out:
# /ext3/miniforge/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /ext3/miniforge/lib/python3.10/site-packages/dask/core.py:127: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
plt.figure(figsize=(12, 10))

plt.subplot(1,2,1)
diss_C0.mean('time').sum('zl').plot(robust=True)


plt.subplot(1,2,2)
diss_Cp2.mean('time').sum('zl').plot(robust=True)


plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 plt.figure(figsize=(12, 10))
#       3 plt.subplot(1,2,1)
# ----> 4 diss_C0.mean('time').sum('zl').plot(robust=True)
#       7 plt.subplot(1,2,2)
#       8 diss_Cp2.mean('time').sum('zl').plot(robust=True)
#
# NameError: name 'diss_C0' is not defined

# %%
plt.figure(figsize=(12, 10))

vmin = - 20
plt.subplot(1,2,1)
diss_C0.mean('time').sum('zl').plot(vmin=vmin)


plt.subplot(1,2,2)
diss_Cp2.mean('time').sum('zl').plot(vmin=vmin)


plt.tight_layout()

# %%
vmin = -10
diss_Cp2.mean('time').sum('zl').plot(vmin=vmin)
