# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
dir_noparam = '/scratch/db194/mom6/nov2024/NeverWorld/bare/output/'
dir_NGM = '/scratch/db194/mom6/nov2024/NeverWorld/NGM/output/'

# %%
stats_noparam = xr.open_dataset(dir_noparam+'ocean.stats.nc')

# %%
stats_NGM = xr.open_dataset(dir_NGM+'ocean.stats.nc')

# %%
stats_noparam.APE.sum('Interface').plot()
stats_NGM.APE.sum('Interface').plot()
plt.xlim([0, 8e15])
plt.ylim([0, 1e17])
# Out:
# (0.0, 1e+17)
