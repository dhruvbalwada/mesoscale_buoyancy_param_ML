# %%
import xarray as xr
import matplotlib.pyplot as plt
from xgcm import Grid
import numpy as np

# %%
exp_dir = '/scratch/db194/mom6/base_experiments_2025/DoubleGyre/DoubleGyre_ANN_template_test_run/OUTPUT/'

# %%
ds = xr.open_dataset(exp_dir + 'prog_00005.nc', decode_times=False)

# %%
ds_ave = xr.open_dataset(exp_dir + 'ave_prog_00002.nc', decode_times=False)

# %%
ds.Fy.isel(Time=0).plot(col='zl', robust=True)

# %%
ds.dhdx.isel(Time=0).plot(col='zl', robust=True)

# %%
ds.dhbardx.isel(Time=0).plot(col='zl', robust=True)
