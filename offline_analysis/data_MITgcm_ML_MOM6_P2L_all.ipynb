# %% [markdown]
# ## MITgcm data
# ## MOM6 allmodel

# %%
import sys 
sys.path.append('../modules/')

# %%
# %reload_ext autoreload
# %autoreload 2
import evaluation
# Out:
# WARNING:absl:GlobalAsyncCheckpointManager is not imported correctly. Checkpointing of GlobalDeviceArrays will not be available.To use the feature, install tensorstore.

# %%
model_nc  = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_model_ncs/MOM6_P2L_all_36_36.nc'
data_kind = 'MITgcm' 
exp_name  = '' 
ML_name   = 'all'

# %%
eval_dic = {}
Lkeys = ['50', '100', '200', '400']
for L in Lkeys: 
    data_zarr = 'gs://leap-persistent/dhruvbalwada/m2lines_transfer/ML_data/ds_ML_'+L+'km_3D'
    eval_dic[L] = evaluation.full_reader(model_nc, data_zarr, L, data_kind, exp_name, ML_name, 
                                        Tdim='time')
# Out:
# WARNING:jax._src.xla_bridge:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Dataset loaded from gs://leap-persistent/dhruvbalwada/m2lines_transfer/ML_data/ds_ML_50km_3D
# Centered
# Normalized data
# Dataset loaded from gs://leap-persistent/dhruvbalwada/m2lines_transfer/ML_data/ds_ML_100km_3D
# Centered
# Normalized data
# Dataset loaded from gs://leap-persistent/dhruvbalwada/m2lines_transfer/ML_data/ds_ML_200km_3D
# Centered
# Normalized data
# Dataset loaded from gs://leap-persistent/dhruvbalwada/m2lines_transfer/ML_data/ds_ML_400km_3D
# Centered
# Normalized data

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a figure and axis objects
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))

# Iterate through the keys '50km', '100km', '200km', and '400km' and plot each dataset
for i, key in enumerate(['50', '100', '200', '400']):
    values = eval_dic[key]
    ds_true = values.output_ds.Sfny.isel(time=-1, Z=2)
    ds_pred = values.output_pred_ds.Sfny.isel(time=-1, Z=2)
    ds_anomaly = ds_true - ds_pred

    # Plotting true values
    ds_true.plot(ax=axs[0,i], vmin=ds_true.min().values)
    axs[0,i].set_title(f'{key} - True')
    
    # Plotting predicted values
    ds_pred.plot(ax=axs[1,i], vmin=ds_true.min().values)
    axs[1,i].set_title(f'{key} - Predicted')
    
    # Plotting anomaly values
    ds_anomaly.plot(ax=axs[2,i], vmin=ds_true.min().values)
    axs[2,i].set_title(f'{key} - Anomaly')
    
    # Set title and labels
    for j in range(3):
        axs[j,i].set_xlabel('X [km]')
        axs[j,i].set_ylabel('Y [km]')

    
# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
#plt.show()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcm_all_panels.png')

# %% [markdown]
# ## Metrics:

# %% [markdown]
# ### Pointwise

# %%
Lkeys = ['50', '100', '200', '400']
print('R2:')
for L in Lkeys: 
    print(L + ': ' + str(eval_dic[L].calc_R2(dims=['time','XC','YC','Z']).values) )
# Out:
# R2:
# 50: 0.5060478
# 100: 0.75477874
# 200: 0.42619234
# 400: -0.020357966

# %%
Lkeys = ['50', '100', '200', '400']
print('Corr:')
for L in Lkeys: 
    print(L + ': ' + str(eval_dic[L].calc_corr(dims=['time','XC','YC','Z']).values) )
# Out:
# Corr:
# 50: 0.8812528831179843
# 100: 0.878777962261929
# 200: 0.7352971215692725
# 400: 0.34280024519251756

# %%
Lkeys = ['50', '100', '200', '400']
print('R2:')
for L in Lkeys: 
    eval_dic[L].calc_R2(dims=['time','XC','YC']).plot(y='Z',label=L)
plt.legend()
# Out:
# R2:

# %%
Lkeys = ['50', '100', '200', '400']
print('R2:')
for L in Lkeys: 
    eval_dic[L].calc_corr(dims=['time','XC','YC']).plot(y='Z',label=L)
plt.legend()
# Out:
# R2:

# %% [markdown]
# ### Spectral

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_ps, pred_ps, anom_ps = eval_dic[L].zonal_PS_P2L(var='Sfny', 
                                                     avg_dims=['Time','yh'])
    plt.subplot(1,4,i+1)
    (true_ps * true_ps.freq_xh).plot(label='True')
    (pred_ps * pred_ps.freq_xh).plot(label='Pred')
    (anom_ps * anom_ps.freq_xh).plot(label='Anomaly')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('k [1/m]')
    plt.title(L+'km')

plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_spectra.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataarray.py:835, in DataArray._getitem_coord(self, key)
#     834 try:
# --> 835     var = self._coords[key]
#     836 except KeyError:
#
# KeyError: 'xh'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4044/1063916947.py in ?()
#       1 plt.figure(figsize=(14, 3))
#       2
#       3 for i,L in enumerate(Lkeys):
# ----> 4     true_ps, pred_ps, anom_ps = eval_dic[L].zonal_PS_P2L(var='Sfny',
#       5                                                      avg_dims=['Time','yh'])
#       6     plt.subplot(1,4,i+1)
#       7     (true_ps * true_ps.freq_xh).plot(label='True')
#
# ~/mesoscale_buoyancy_param_ML/offline_analysis/../modules/evaluation.py in ?(self, var, avg_dims)
#     192     def zonal_PS_P2L(self, var='Sfny', avg_dims=['Time','yh']):
# --> 193         ps_true = xrft.power_spectrum(self.output_ds[var], 'xh')
#     194
#     195         ps_pred = xrft.power_spectrum(self.output_pred_ds[var],'xh')
#     196
#
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xrft/xrft.py in ?(da, dim, real_dim, scaling, window_correction, **kwargs)
#     736     kwargs.update(
#     737         {"true_amplitude": True, "true_phase": False}
#     738     )  # true_phase do not matter in power_spectrum
#     739
# --> 740     daft = fft(da, dim=dim, real_dim=real_dim, **kwargs)
#     741     updated_dims = [
#     742         d for d in daft.dims if (d not in da.dims and "segment" not in d)
#     743     ]  # Transformed dimensions
#
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xrft/xrft.py in ?(da, spacing_tol, dim, real_dim, shift, detrend, window, true_phase, true_amplitude, chunks_to_segments, prefix, **kwargs)
#     351                 real_dim
#     352             ]  # real dim has to be moved or added at the end !
#     353
#     354     if not np.all(
# --> 355         [
#     356             (
#     357                 is_numeric_dtype(da.coords[d])
#     358                 or is_datetime64_any_dtype(da.coords[d])
#
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xrft/xrft.py in ?(.0)
#     355 def fft(
#     356     da,
# --> 357     spacing_tol=1e-3,
#     358     dim=None,
#     359     real_dim=None,
#     360     shift=True,
#
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/coordinates.py in ?(self, key)
#     673     def __getitem__(self, key: Hashable) -> T_DataArray:
# --> 674         return self._data._getitem_coord(key)
#
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataarray.py in ?(self, key)
#     834         try:
#     835             var = self._coords[key]
#     836         except KeyError:
#     837             dim_sizes = dict(zip(self.dims, self.shape))
# --> 838             _, key, var = _get_virtual_variable(self._coords, key, dim_sizes)
#     839
#     840         return self._replace_maybe_drop_dims(var, name=key)
#
# /srv/conda/envs/notebook/lib/python3.10/site-packages/xarray/core/dataset.py in ?(variables, key, dim_sizes)
#     196         raise KeyError(key)
#     197
#     198     split_key = key.split(".", 1)
#     199     if len(split_key) != 2:
# --> 200         raise KeyError(key)
#     201
#     202     ref_name, var_name = split_key
#     203     ref_var = variables[ref_name]
#
# KeyError: 'xh'

# %% [markdown]
# ### Bulk

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(avg_dims=['Time','xh'])
    
    plt.subplot(1,4,i+1)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()
plt.legend()

plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_OT.png')
