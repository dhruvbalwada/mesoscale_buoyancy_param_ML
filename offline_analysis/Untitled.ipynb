# %%
import xarray as xr
import numpy as np 
import matplotlib.pyplot as plt
from datatree import DataTree
from datatree import open_datatree

import xgcm

import sys
sys.path.append('../modules/')
import helper_func as hf

# Import seaborn
import seaborn as sns

# %%
import os
PERSISTENT_BUCKET = os.environ['PERSISTENT_BUCKET']
data_bucket = 'gs://leap-persistent/dhruvbalwada/MOM6/Phillips2Layer/'

# %%
Lkey = ['50', '100', '200', '400']

res_name = 'all'

ds = {}

for L in Lkey: 
    Lsel = int(L)

    ds_temp = xr.open_zarr(f'{data_bucket}res4km_sponge10day_long_ml_data_'+L+'km.zarr').sel(yh=slice(float(Lsel), 1600-float(Lsel)))
    
    ds[L] = ds_temp 

ds_tree = DataTree.from_dict(ds)

# %%
ds_tree
# Out:
# DataTree('None', parent=None)
# ├── DataTree('50')
# │       Dimensions:    (Time: 7200, zl: 2, yh: 188, xh: 150, zi: 3)
# │       Coordinates:
# │         * Time       (Time) object 58kB 0001-01-11 00:00:00 ... 0198-02-16 00:00:00
# │         * xh         (xh) float64 1kB 4.0 12.0 20.0 ... 1.18e+03 1.188e+03 1.196e+03
# │         * yh         (yh) float64 2kB 52.0 60.0 68.0 ... 1.532e+03 1.54e+03 1.548e+03
# │         * zi         (zi) float64 24B 1.03e+03 1.032e+03 1.034e+03
# │         * zl         (zl) float64 16B 1.031e+03 1.033e+03
# │       Data variables: (12/26)
# │           dudx       (Time, zl, yh, xh) float32 2GB dask.array<chunksize=(72, 2, 188, 150), meta=np.ndarray>
# │           dudy       (Time, zl, yh, xh) float32 2GB dask.array<chunksize=(72, 2, 188, 150), meta=np.ndarray>
# │           dvdx       (Time, zl, yh, xh) float32 2GB dask.array<chunksize=(72, 2, 188, 150), meta=np.ndarray>
# ...

# %%
ds_tree['100'].ds.uh_sg.isel(Time=-1)
# Out:
# <xarray.DataArray 'uh_sg' (zl: 2, yh: 70, xh: 60)> Size: 67kB
# dask.array<getitem, shape=(2, 70, 60), dtype=float64, chunksize=(2, 70, 60), chunktype=numpy.ndarray>
# Coordinates:
#     Time     object 8B 0198-02-16 00:00:00
#   * xh       (xh) float64 480B 10.0 30.0 50.0 ... 1.15e+03 1.17e+03 1.19e+03
#   * yh       (yh) float64 560B 110.0 130.0 150.0 ... 1.45e+03 1.47e+03 1.49e+03
#   * zl       (zl) float64 16B 1.031e+03 1.033e+03

# %%
ds_tree['100'].ds.uh_sg.isel(Time=-1).plot(col='zl')

# %%
ds_tree['100'].ds.vh_sg.isel(Time=-1).plot(col='zl')

# %%
ds_tree['400'].ds.vh_sg.isel(Time=-1).plot(col='zl')

# %%
ds_tree['100'].ds.vh_sg.sum('zl').isel(Time=-1).plot.hist(density=True)
ds_tree['100'].ds.vh_sg.isel(zl=1).isel(Time=-1).plot.hist(density=True)


ds_tree['100'].ds.vh_sg.isel(zl=1).mean('Time').plot.hist(density=True)
ds_tree['100'].ds.vh_sg.isel(zl=0).mean('Time').plot.hist(density=True)
ds_tree['100'].ds.vh_sg.sum('zl').mean('Time').plot.hist(density=True)
plt.yscale('log')

# %%
ds_tree['100'].ds.vh_sg.sum('zl').isel(Time=-1).plot.hist(density=True)
ds_tree['100'].ds.vh_sg.isel(zl=0).isel(Time=-1).plot.hist(density=True)
ds_tree['100'].ds.vh_sg.isel(zl=1).isel(Time=-1).plot.hist(density=True)
# Out:
# (array([0.00103274, 0.00206549, 0.00335642, 0.00994016, 0.02013851,
#         0.04995899, 0.38327712, 0.06648289, 0.00516372, 0.00077456]),
#  array([-12.64126665, -10.79689678,  -8.95252692,  -7.10815705,
#          -5.26378719,  -3.41941732,  -1.57504746,   0.26932241,
#           2.11369227,   3.95806214,   5.802432  ]),
#  <BarContainer object of 10 artists>)
