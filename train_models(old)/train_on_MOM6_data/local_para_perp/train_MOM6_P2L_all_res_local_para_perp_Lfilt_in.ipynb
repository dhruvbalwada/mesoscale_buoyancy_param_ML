# %%
import sys
sys.path.append('../../../modules/')

# %reload_ext autoreload
# %autoreload 2
import datasets
import ML_classes

import matplotlib.pyplot as plt
# Out:
# 2024-09-05 19:40:03.584529: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-05 19:40:03.584558: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-05 19:40:03.585798: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
MOM6_bucket = 'gs://leap-persistent/dhruvbalwada/MOM6/Phillips2Layer/'
L = 'all'

# %%
ML_data = datasets.MOM6_all_transformer('-', 'all')

# %%
ML_data.read_datatree(MOM6_bucket, 
                      keep_filt_scale=True, para_perp_out = True)
# Out:
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Phillips2Layer/res4km_sponge10day_long_ml_data_50km.zarr
# Out para perp
# Subsampling
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Phillips2Layer/res4km_sponge10day_long_ml_data_100km.zarr
# Out para perp
# Subsampling
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Phillips2Layer/res4km_sponge10day_long_ml_data_200km.zarr
# Out para perp
# Subsampling
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Phillips2Layer/res4km_sponge10day_long_ml_data_400km.zarr
# Out para perp
# Subsampling

# %%
plt.figure(figsize=(10, 8))

plt.subplot(221)
ML_data.datatree['50'].Sfnx.isel(Time=-1).plot(robust=True)
plt.grid()

plt.subplot(222)
ML_data.datatree['100'].Sfnx.isel(Time=-1).plot(robust=True)

plt.grid()

plt.subplot(223)
ML_data.datatree['200'].Sfnx.isel(Time=-1).plot(robust=True)

plt.grid()

plt.subplot(224)
ML_data.datatree['400'].Sfnx.isel(Time=-1).plot(robust=True)

plt.grid()

plt.tight_layout()

# %%
ML_data.datatree
# Out:
# DataTree('None', parent=None)
# ├── DataTree('50')
# │       Dimensions:  (Time: 7200, yh: 13, xh: 19)
# │       Coordinates:
# │         * Time     (Time) object 58kB 0001-01-11 00:00:00 ... 0198-02-16 00:00:00
# │         * xh       (xh) float64 152B 4.0 68.0 132.0 ... 1.028e+03 1.092e+03 1.156e+03
# │         * yh       (yh) float64 104B 404.0 468.0 532.0 ... 1.108e+03 1.172e+03
# │           zl       float64 8B 1.033e+03
# │       Data variables:
# │           Sfnx     (Time, yh, xh) float64 14MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           Sfny     (Time, yh, xh) float64 14MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           U_x      (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           U_y      (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           V_x      (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           V_y      (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           Sx       (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           Sy       (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# │           Lfilt    (Time, yh, xh) float32 7MB dask.array<chunksize=(72, 13, 19), meta=np.ndarray>
# ├── DataTree('100')
# │       Dimensions:  (Time: 7200, yh: 10, xh: 15)
# │       Coordinates:
# │         * Time     (Time) object 58kB 0001-01-11 00:00:00 ... 0198-02-16 00:00:00
# │         * xh       (xh) float64 120B 10.0 90.0 170.0 250.0 ... 970.0 1.05e+03 1.13e+03
# │         * yh       (yh) float64 80B 410.0 490.0 570.0 ... 970.0 1.05e+03 1.13e+03
# │           zl       float64 8B 1.033e+03
# │       Data variables:
# │           Sfnx     (Time, yh, xh) float64 9MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Sfny     (Time, yh, xh) float64 9MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           U_x      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           U_y      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           V_x      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           V_y      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Sx       (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Sy       (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Lfilt    (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# ├── DataTree('200')
# │       Dimensions:  (Time: 7200, yh: 10, xh: 15)
# │       Coordinates:
# │         * Time     (Time) object 58kB 0001-01-11 00:00:00 ... 0198-02-16 00:00:00
# │         * xh       (xh) float64 120B 20.0 100.0 180.0 ... 980.0 1.06e+03 1.14e+03
# │         * yh       (yh) float64 80B 420.0 500.0 580.0 ... 980.0 1.06e+03 1.14e+03
# │           zl       float64 8B 1.033e+03
# │       Data variables:
# │           Sfnx     (Time, yh, xh) float64 9MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Sfny     (Time, yh, xh) float64 9MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           U_x      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           U_y      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           V_x      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           V_y      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Sx       (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Sy       (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# │           Lfilt    (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
# └── DataTree('400')
#         Dimensions:  (Time: 7200, yh: 10, xh: 15)
#         Coordinates:
#           * Time     (Time) object 58kB 0001-01-11 00:00:00 ... 0198-02-16 00:00:00
#           * xh       (xh) float64 120B 40.0 120.0 200.0 ... 1e+03 1.08e+03 1.16e+03
#           * yh       (yh) float64 80B 440.0 520.0 600.0 ... 1e+03 1.08e+03 1.16e+03
#             zl       float64 8B 1.033e+03
#         Data variables:
#             Sfnx     (Time, yh, xh) float64 9MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             Sfny     (Time, yh, xh) float64 9MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             U_x      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             U_y      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             V_x      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             V_y      (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             Sx       (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             Sy       (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>
#             Lfilt    (Time, yh, xh) float32 4MB dask.array<chunksize=(72, 10, 15), meta=np.ndarray>

# %%
ML_data.generate_test_train_batches(normalize=False)
# Out:
# Test and train batches split. Number of batches: 37-5

# %%
ML_data.ds_train
# Out:
# <xarray.Dataset> Size: 303MB
# Dimensions:  (points: 3983040)
# Coordinates:
#     zl       float64 8B 1.033e+03
#   * points   (points) object 32MB MultiIndex
#   * Time     (points) object 32MB 0073-11-09 00:00:00 ... 0012-06-02 00:00:00
#   * xh       (points) float64 32MB 580.0 132.0 970.0 660.0 ... 10.0 740.0 570.0
#   * yh       (points) float64 32MB 740.0 404.0 1.13e+03 ... 1.06e+03 1.05e+03
# Data variables:
#     Sfnx     (points) float64 32MB -0.7163 -3.549e-05 0.1569 ... -3.686 -1.449
#     Sfny     (points) float64 32MB 0.7531 -0.001611 -0.1956 ... 2.937 1.627
#     U_x      (points) float32 16MB -8.617e-07 -4.212e-07 ... -2.778e-08
#     U_y      (points) float32 16MB 1.828e-07 2.806e-07 ... -1.199e-06 1.042e-06
#     V_x      (points) float32 16MB -4.927e-07 -3.854e-07 ... 6.217e-09 5.698e-07
#     V_y      (points) float32 16MB 9.601e-07 4.242e-07 ... 3.109e-07 2.313e-08
#     Sx       (points) float32 16MB -2.695e-05 1.934e-05 ... 0.001179 -0.0009887
#     Sy       (points) float32 16MB 0.0001123 -1.028e-05 ... 0.001057 0.001254
#     Lfilt    (points) float32 16MB 200.0 50.0 100.0 200.0 ... 100.0 200.0 100.0

# %%
ANN_model = ML_classes.ANN(num_in = len(ML_data.input_channels))

# %%
regress_sys = ML_classes.RegressionSystem(ANN_model, local_norm=True)

# %%
# %%time
regress_sys.train_system(ML_data, 31, 1)
# Out:
# Train loss step 0:  24.462585011044062 test loss: 6.1954466819763185
# Train loss step 1:  5.997315161936992 test loss: 4.81030797958374
# Train loss step 2:  5.086141818278545 test loss: 4.322142505645752
# Train loss step 3:  4.670899868011475 test loss: 4.023167943954467
# Train loss step 4:  4.4086922568243905 test loss: 3.840419340133667
# Train loss step 5:  4.24339129473712 test loss: 3.716132116317749
# Train loss step 6:  4.126931602890427 test loss: 3.631550979614258
# Train loss step 7:  4.048659943245553 test loss: 3.573345184326172
# Train loss step 8:  3.9925793506003715 test loss: 3.528901767730713
# Train loss step 9:  3.9482431282868258 test loss: 3.4923732757568358
# Train loss step 10:  3.9112938932470374 test loss: 3.4604483127593992
# Train loss step 11:  3.8795405658515723 test loss: 3.4331079006195067
# Train loss step 12:  3.852321399224771 test loss: 3.409948301315308
# Train loss step 13:  3.828588292405412 test loss: 3.38988995552063
# Train loss step 14:  3.8078822831849792 test loss: 3.3718785285949706
# Train loss step 15:  3.7898078158095077 test loss: 3.3564804077148436
# Train loss step 16:  3.7742566482440845 test loss: 3.3425567150115967
# Train loss step 17:  3.76013318912403 test loss: 3.3294323444366456
# Train loss step 18:  3.746879783836571 test loss: 3.317247200012207
# Train loss step 19:  3.7342480968784644 test loss: 3.3057303428649902
# Train loss step 20:  3.7218913387607886 test loss: 3.294609022140503
# Train loss step 21:  3.7101109607799634 test loss: 3.283783960342407
# Train loss step 22:  3.6990941666268013 test loss: 3.27372784614563
# Train loss step 23:  3.6885734506555505 test loss: 3.2647198677062987
# Train loss step 24:  3.6787660959604622 test loss: 3.2563061237335207
# Train loss step 25:  3.6696018012794287 test loss: 3.2484489917755126
# Train loss step 26:  3.6605655438191183 test loss: 3.2403868198394776
# Train loss step 27:  3.651440884615924 test loss: 3.230902671813965
# Train loss step 28:  3.641876407571741 test loss: 3.22201247215271
# Train loss step 29:  3.632149329056611 test loss: 3.213347148895264
# Train loss step 30:  3.62206388164211 test loss: 3.2041777610778808
# CPU times: user 11min 41s, sys: 3.55 s, total: 11min 45s
# Wall time: 10min 27s

# %%
# Save the checkpoint
CKPT_DIR = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_checkpoints/ckpts_all_MOM6_P2L_window_1_local_norm_true_out_para_perp_Lfilt_in'
regress_sys.save_checkpoint(CKPT_DIR)

# Save model nc file
model_nc = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_model_ncs/' +'MOM6_P2L_all_window_1_local_norm_true_out_para_perp_Lfilt_in'+'.nc'
regress_sys.save_weights_nc(model_nc)

# %%
## Loss plot
plt.plot(regress_sys.train_loss, label='Training loss, '+str(regress_sys.train_loss[-1]))
plt.plot(regress_sys.test_loss, label='Test loss'+str(regress_sys.test_loss[-1]))

plt.title('Loss curve for '+ L+ 'km filter scale')
plt.grid()
plt.yscale('log')
plt.legend()

#plt.savefig('figures/MOM6_'+L+'km_loss_curve_36_36.png')

# %%
ANN_model_large = ML_classes.ANN(shape=[36,36,2], num_in = len(ML_data.input_channels))

# %%
regress_sys_large = ML_classes.RegressionSystem(ANN_model_large, local_norm=True)

# %%
# %%time
regress_sys_large.train_system(ML_data, 31, 1)
# Out:
# Train loss step 0:  10.386479725708833 test loss: 5.008446979522705
# Train loss step 1:  5.3289203257174105 test loss: 4.631331157684326
# Train loss step 2:  5.096102946513408 test loss: 4.517623043060302
# Train loss step 3:  5.016205310821533 test loss: 4.464121723175049
# Train loss step 4:  4.970989214407431 test loss: 4.429570484161377
# Train loss step 5:  4.938185872258367 test loss: 4.405003261566162
# Train loss step 6:  4.9112177281766325 test loss: 4.382707977294922
# Train loss step 7:  4.888203221398431 test loss: 4.360996437072754
# Train loss step 8:  4.868420781315984 test loss: 4.349296951293946
# Train loss step 9:  4.853387020729683 test loss: 4.338255786895752
# Train loss step 10:  4.840775631569527 test loss: 4.325668811798096
# Train loss step 11:  4.8302396181467415 test loss: 4.320721626281738
# Train loss step 12:  4.82325485590342 test loss: 4.315691947937012
# Train loss step 13:  4.8169844472730485 test loss: 4.306829261779785
# Train loss step 14:  4.810959687104097 test loss: 4.2975787162780765
# Train loss step 15:  4.804880722148998 test loss: 4.290812397003174
# Train loss step 16:  4.800004598256704 test loss: 4.285268497467041
# Train loss step 17:  4.795854916443696 test loss: 4.28159646987915
# Train loss step 18:  4.792591533145389 test loss: 4.278890895843506
# Train loss step 19:  4.789993105707942 test loss: 4.276395225524903
# Train loss step 20:  4.7875448433128565 test loss: 4.27363224029541
# Train loss step 21:  4.7853724892075 test loss: 4.271508121490479
# Train loss step 22:  4.783574130084063 test loss: 4.2699119567871096
# Train loss step 23:  4.782231176221693 test loss: 4.2685826301574705
# Train loss step 24:  4.781049767056027 test loss: 4.267539691925049
# Train loss step 25:  4.779790968508334 test loss: 4.266379451751709
# Train loss step 26:  4.77858152905026 test loss: 4.265265655517578
# Train loss step 27:  4.777165580440212 test loss: 4.263956069946289
# Train loss step 28:  4.775650423926276 test loss: 4.262798213958741
# Train loss step 29:  4.774287494453224 test loss: 4.26197624206543
# Train loss step 30:  4.772950120874353 test loss: 4.2612813949584964
# CPU times: user 11min 56s, sys: 3.4 s, total: 12min
# Wall time: 10min 2s

# %%
# Save the checkpoint
CKPT_DIR = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_checkpoints/ckpts_all_MOM6_P2L_window_1_local_norm_true_out_para_perp_size_36_36'
regress_sys.save_checkpoint(CKPT_DIR)

# Save model nc file
model_nc = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_model_ncs/' +'MOM6_P2L_all_window_1_local_norm_true_out_para_perp_size_36_36'+'.nc'
regress_sys.save_weights_nc(model_nc)
