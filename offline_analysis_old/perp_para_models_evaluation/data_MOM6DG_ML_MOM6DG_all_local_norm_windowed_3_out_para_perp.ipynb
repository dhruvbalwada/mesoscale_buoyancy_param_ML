# %% [markdown]
# ## MOM6 data DG
# ## MOM6model DG
# ## local norm
# ## Window 3

# %%
import sys 
sys.path.append('../../modules/')

# %%
# %reload_ext autoreload
# %autoreload 2
import evaluation
# Out:
# 2024-03-18 13:53:53.318341: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-18 13:53:53.318385: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-18 13:53:53.318392: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#model_nc  = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_model_ncs/MOM6_DG_all_window_3_local_norm_true_out_para_perp.nc'
model_nc  = '/home/jovyan/mesoscale_buoyancy_param_ML/ML_model_ncs/MOM6_DG_all_window_3_local_norm_true_out_para_perp.nc'
data_kind = 'MOM6_DG' 
exp_name  = 'DG' 
ML_name   = 'all'

# %%
MOM6_bucket = 'gs://leap-persistent/dhruvbalwada/MOM6/Double_Gyre/'

# %%
eval_dic = {}
Lkeys = ['50', '100', '200', '400']
for L in Lkeys: 
    eval_dic[L] = evaluation.full_reader(model_nc, MOM6_bucket, 
                                          L, data_kind, 
                                          exp_name,
                                          ML_name='all',
                                          Tdim='Time',
                                          local_norm=True, out_para_perp=True,
                                          windowed=True, window_size=3,
                                          dims_input=['Time','yh','xh'])
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# Local normed and windowed
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Double_Gyre/res5km/ml_data_50km.zarr
# Out para perp
# Local normed and windowed
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Double_Gyre/res5km/ml_data_100km.zarr
# Out para perp
# Local normed and windowed
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Double_Gyre/res5km/ml_data_200km.zarr
# Out para perp
# Local normed and windowed
# Dataset loaded from gs://leap-persistent/dhruvbalwada/MOM6/Double_Gyre/res5km/ml_data_400km.zarr
# Out para perp

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a figure and axis objects
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))
nt=-10
# Iterate through the keys '50km', '100km', '200km', and '400km' and plot each dataset
for i, key in enumerate(['50', '100', '200', '400']):
    values = eval_dic[key]
    ds_true = values.output_ds.Sfny.isel(Time=nt)
    ds_pred = values.output_pred_ds.Sfny.isel(Time=nt)
    ds_anomaly = ds_true - ds_pred

    # Plotting true values
    ds_true.plot(ax=axs[0,i], vmin=ds_true.min().values)
    axs[0,i].set_title(f'{key} - True')
    
    # Plotting predicted values
    ds_pred.plot(ax=axs[1,i], vmin=ds_true.min().values)
    axs[1,i].set_title(f'{key} - Predicted')
    
    # Plotting anomaly values
    ds_anomaly.plot(ax=axs[2,i], vmin=ds_true.min().values)
    axs[2,i].set_title(f'{key} - Anomaly')
    
    # Set title and labels
    for j in range(3):
        axs[j,i].set_xlabel('X [km]')
        axs[j,i].set_ylabel('Y [km]')
        axs[j,i].set_ylim(30,50)
    
# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
#plt.show()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcm_all_panels.png')

# %%
# Create a figure and axis objects
nt=-1

fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))
# Iterate through the keys '50km', '100km', '200km', and '400km' and plot each dataset
for i, key in enumerate(['50', '100', '200', '400']):
    values = eval_dic[key]
    ds_true = values.output_ds.Sfnx.isel(Time=nt)
    ds_pred = values.output_pred_ds.Sfnx.isel(Time=nt)
    ds_anomaly = ds_true - ds_pred

    # Plotting true values
    ds_true.plot(ax=axs[0,i], vmin=ds_true.min().values)
    axs[0,i].set_title(f'{key} - True')
    axs[0,i].set_ylim(30,50)
    
    # Plotting predicted values
    ds_pred.plot(ax=axs[1,i], vmin=ds_true.min().values)
    axs[1,i].set_title(f'{key} - Predicted')
    axs[1,i].set_ylim(30,50)
    
    # Plotting anomaly values
    ds_anomaly.plot(ax=axs[2,i], vmin=ds_true.min().values)
    axs[2,i].set_title(f'{key} - Anomaly')
    axs[2,i].set_ylim(30,50)
    
    # Set title and labels
    for j in range(3):
        axs[j,i].set_xlabel('X [km]')
        axs[j,i].set_ylabel('Y [km]')

    
# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
#plt.show()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcm_all_panels.png')

# %%
# Create a figure and axis objects
nt=0

fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))
# Iterate through the keys '50km', '100km', '200km', and '400km' and plot each dataset
for i, key in enumerate(['50', '100', '200', '400']):
    values = eval_dic[key]
    ds_true = values.output_ds.Sfny.mean('Time')
    ds_pred = values.output_pred_ds.Sfny.mean('Time')
    ds_anomaly = ds_true - ds_pred

    # Plotting true values
    ds_true.plot(ax=axs[0,i], vmin=ds_true.min().values)
    axs[0,i].set_title(f'{key} - True')
    axs[0,i].set_ylim(30,50)
    
    # Plotting predicted values
    ds_pred.plot(ax=axs[1,i], vmin=ds_true.min().values)
    axs[1,i].set_title(f'{key} - Predicted')
    axs[1,i].set_ylim(30,50)
    
    # Plotting anomaly values
    ds_anomaly.plot(ax=axs[2,i], vmin=ds_true.min().values)
    axs[2,i].set_title(f'{key} - Anomaly')
    axs[2,i].set_ylim(30,50)
    
    # Set title and labels
    for j in range(3):
        axs[j,i].set_xlabel('X [km]')
        axs[j,i].set_ylabel('Y [km]')

    
# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
#plt.show()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcm_all_panels.png')

# %%
# Create a figure and axis objects
nt=0

fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))
# Iterate through the keys '50km', '100km', '200km', and '400km' and plot each dataset
for i, key in enumerate(['50', '100', '200', '400']):
    values = eval_dic[key]
    ds_true = values.output_ds.Sfnx.mean('Time')
    ds_pred = values.output_pred_ds.Sfnx.mean('Time')
    ds_anomaly = ds_true - ds_pred

    # Plotting true values
    ds_true.plot(ax=axs[0,i], vmin=ds_true.min().values)
    axs[0,i].set_title(f'{key} - True')
    axs[0,i].set_ylim(30,50)
    
    # Plotting predicted values
    ds_pred.plot(ax=axs[1,i], vmin=ds_true.min().values)
    axs[1,i].set_title(f'{key} - Predicted')
    axs[1,i].set_ylim(30,50)
    
    # Plotting anomaly values
    ds_anomaly.plot(ax=axs[2,i], vmin=ds_true.min().values)
    axs[2,i].set_title(f'{key} - Anomaly')
    axs[2,i].set_ylim(30,50)
    
    # Set title and labels
    for j in range(3):
        axs[j,i].set_xlabel('X [km]')
        axs[j,i].set_ylabel('Y [km]')

    
# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
#plt.show()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcm_all_panels.png')

# %% [markdown]
# ## Metrics:

# %% [markdown]
# ### Pointwise

# %%
Lkeys = ['50', '100', '200', '400']
print('R2:')
for L in Lkeys: 
    print(L + ': ' + str(eval_dic[L].calc_R2(dims=['Time','xh','yh']).values) )
# Out:
# R2:
# 50: 0.88414735
# 100: 0.85674226
# 200: 0.7146928
# 400: 0.4645676

# %%
Lkeys = ['50', '100', '200', '400']
print('Corr:')
for L in Lkeys: 
    print(L + ': ' + str(eval_dic[L].calc_corr(dims=['Time','xh','yh']).values) )
# Out:
# Corr:
# 50: 0.94266593
# 100: 0.9296537
# 200: 0.8522703
# 400: 0.74430174

# %%
Lkeys = ['50', '100', '200', '400']
print('R2:')
for L in Lkeys: 
    print(L + ': ' + str(eval_dic[L].calc_R2(var='Sfny',dims=['Time','xh','yh']).values) )
# Out:
# R2:
# 50: 0.937549
# 100: 0.9278236
# 200: 0.8563961
# 400: 0.64439833

# %%
Lkeys = ['50', '100', '200', '400']
print('Corr:')
for L in Lkeys: 
    print(L + ': ' + str(eval_dic[L].calc_corr(var='Sfny',dims=['Time','xh','yh']).values) )
# Out:
# Corr:
# 50: 0.9685361
# 100: 0.9628295
# 200: 0.91763514
# 400: 0.7939976

# %%
print('R2:')
for L in Lkeys: 
    R2_mean = 0.5*(eval_dic[L].calc_R2(var='Sfnx',dims=['Time','xh','yh']).values + 
                   eval_dic[L].calc_R2(var='Sfny',dims=['Time','xh','yh']).values) 
    print(L + ': ' + str(R2_mean) )
# Out:
# R2:
# 50: 0.9216848611831665
# 100: 0.9054742455482483
# 200: 0.8050030469894409
# 400: 0.5957083106040955

# %%
print('Corr:')
for L in Lkeys: 
    R2_mean = 0.5*(eval_dic[L].calc_corr(var='Sfnx',dims=['Time','xh','yh']).values + 
                   eval_dic[L].calc_corr(var='Sfny',dims=['Time','xh','yh']).values) 
    print(L + ': ' + str(R2_mean) )
# Out:
# Corr:
# 50: 0.9610532522201538
# 100: 0.9536575078964233
# 200: 0.895801842212677
# 400: 0.7868081331253052

# %% [markdown]
# ### Spectral

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_ps, pred_ps, anom_ps = eval_dic[L].zonal_PS_P2L(var='Sfny', 
                                                     avg_dims=['Time','yh'])
    plt.subplot(1,4,i+1)
    (true_ps * true_ps.freq_xh).plot(label='True')
    (pred_ps * pred_ps.freq_xh).plot(label='Pred')
    (anom_ps * anom_ps.freq_xh).plot(label='Anomaly')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('k [1/m]')
    plt.title(L+'km')

plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_spectra.png')

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_ps, pred_ps, anom_ps = eval_dic[L].zonal_PS_P2L(var='Sfnx', 
                                                     avg_dims=['Time','yh'])
    plt.subplot(1,4,i+1)
    (true_ps * true_ps.freq_xh).plot(label='True')
    (pred_ps * pred_ps.freq_xh).plot(label='Pred')
    (anom_ps * anom_ps.freq_xh).plot(label='Anomaly')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('k [1/m]')
    plt.title(L+'km')

plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_spectra.png')

# %% [markdown]
# ### Bulk

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(avg_dims=['Time','xh'])
    
    plt.subplot(1,4,i+1)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_OT.png')

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(var='Sfnx', avg_dims=['Time','xh'])
    
    plt.subplot(1,4,i+1)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_OT.png')

# %%
plt.figure(figsize=(14, 6)) 

for i,L in enumerate(Lkeys): 
    eval_dic[L].para_perp_2_xy()
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(var='Sfn_para_y', avg_dims=['Time','xh'])

    plt.subplot(2,4,i+1)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()

for i,L in enumerate(Lkeys): 
    eval_dic[L].para_perp_2_xy()
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(var='Sfn_perp_y', avg_dims=['Time','xh'])

    plt.subplot(2,4,i+5)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()
plt.legend()

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_ps, pred_ps, anom_ps = eval_dic[L].zonal_PS_P2L(var='Sfn_perp_y', 
                                                     avg_dims=['Time','yh'])
    plt.subplot(1,4,i+1)
    (true_ps * true_ps.freq_xh).plot(label='True')
    (pred_ps * pred_ps.freq_xh).plot(label='Pred')
    (anom_ps * anom_ps.freq_xh).plot(label='Anomaly')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(1/1200, 1/10)
    plt.xlabel('k [1/m]')
    plt.title(L+'km')

plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_spectra.png')

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys): 
    true_ps, pred_ps, anom_ps = eval_dic[L].zonal_PS_P2L(var='Sfn_para_y', 
                                                     avg_dims=['Time','yh'])
    plt.subplot(1,4,i+1)
    (true_ps * true_ps.freq_xh).plot(label='True')
    (pred_ps * pred_ps.freq_xh).plot(label='Pred')
    (anom_ps * anom_ps.freq_xh).plot(label='Anomaly')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(1/1200, 1/10)
    plt.xlabel('k [1/m]')
    plt.title(L+'km')

plt.tight_layout()
plt.legend()

#plt.savefig('./figures/data_MOM6p2l_ML_MITgcmall_spectra.png')

# %%
plt.figure(figsize=(14, 6)) 

for i,L in enumerate(Lkeys): 
    eval_dic[L].dissipative_prop()
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(var='Sfn_para_y', avg_dims=['Time','xh'])

    plt.subplot(2,4,i+1)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()

for i,L in enumerate(Lkeys): 
    eval_dic[L].para_perp_2_xy()
    true_OT, pred_OT, anom_OT = eval_dic[L].zonal_avg_OT(var='Sfn_perp_y', avg_dims=['Time','xh'])

    plt.subplot(2,4,i+5)
    (-true_OT).plot(label='True')
    (-pred_OT).plot(label='Pred')
    (-anom_OT).plot(label='Anom')
    plt.title(L+'km')
    
plt.tight_layout()
plt.legend()

# %%
plt.figure(figsize=(14, 3)) 

for i,L in enumerate(Lkeys):
    eval_dic[L].dissipative_prop(Sfnx='Sfn_perp_x', Sfny='Sfn_perp_y', name='perp')

    plt.subplot(1,4,i+1)
    eval_dic[L].output_ds.PE_diss_perp.mean(['Time','xh']).plot()
    eval_dic[L].output_pred_ds.PE_diss_perp.mean(['Time','xh']).plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['50'].output_ds.PE_diss_perp.isel(Time=0).plot()

plt.subplot(122)
eval_dic['50'].output_pred_ds.PE_diss_perp.isel(Time=0).plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['400'].output_ds.PE_diss_perp.isel(Time=0).plot()

plt.subplot(122)
eval_dic['400'].output_pred_ds.PE_diss_perp.isel(Time=0).plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['400'].output_ds.PE_diss_perp.mean('Time').plot()

plt.subplot(122)
eval_dic['400'].output_pred_ds.PE_diss_perp.mean('Time').plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['50'].output_ds.PE_diss_perp.mean('Time').plot()

plt.subplot(122)
eval_dic['50'].output_pred_ds.PE_diss_perp.mean('Time').plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['100'].output_ds.PE_diss_perp.mean('Time').plot()

plt.subplot(122)
eval_dic['100'].output_pred_ds.PE_diss_perp.mean('Time').plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['200'].output_ds.PE_diss_perp.mean('Time').plot()

plt.subplot(122)
eval_dic['200'].output_pred_ds.PE_diss_perp.mean('Time').plot()

plt.tight_layout()

# %%
plt.figure(figsize=(8,3)) 

plt.subplot(121)
eval_dic['400'].output_ds.PE_diss_perp.mean('Time').plot(vmin=-0.008, vmax=0.008, cmap='RdBu_r')

plt.subplot(122)
(4*eval_dic['400'].output_pred_ds.PE_diss_perp).mean('Time').plot(vmin=-0.008, vmax=0.008, cmap='RdBu_r')

plt.tight_layout()
